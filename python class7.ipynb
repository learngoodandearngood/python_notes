# %% [markdown]
# <img src="https://d24cdstip7q8pz.cloudfront.net/t/ineuron1/content/common/images/final%20logo.png" height=60 alt-text="iNeuron.ai logo">

# %% [markdown]
# - What Is A Function ?
#
# - Function V/s Method
#
# - Steps Required For Developing User Defined Function and Calling that Function
#
# - Returning Values From Function
#
# - Arguments V/s Parameters
#
# - Types Of Arguments
#
# - Variable Scope
#
# - Local Scope
#
# - Global Scope
#
# - Argument Passing
#
# - Anonymous Functions OR Lambda Function
#
# - The map( ) Function
#
# - The filter( ) Function
#
# - Using map( ) and filter( ) with Lambda Expressions

# %% [markdown]
# ## 07 Functions
#
# - **Definition**: Function are nothing but a block of code which performs a specific task and can be called again and again as per requirement in the code.
# - A generic way to write a simple function is shown below-
# ```python
# def function_name():
#     # function body starts
#     pass
#     # function body ends
# # calling function in the code -
# function_name()
# ```
#
# - **DRY**: It stands for **D**o not **R**epeat **Y**ourself. It means that a good generally should not contain repeated blocks of code. So if you observe in your code repeatition of certain lines of code then you can also make it a function and call as per your requirement. Let's see an example below-

# %% [markdown]
# ### 7.1 A simple function definition
# **EXAMPLE:**

# %%
def function_name():
    # function body starts
    pass
    # function body ends

# calling function in the code -
function_name()

# %% [markdown]
# **EXAMPLE:**

# %%
def greetings():
    print("Hi there from iNeuron")

# calling greeting function in the code -
greetings()

# %% [markdown]
# - We can also pass some values to the function. These values are known as arguments.A function can have following kind of arguments -
#     - 1. Key word arguments: Here we define the name of arguments

# %% [markdown]
# **EXAMPLE**:
# Observe the below code from Expressions, Operators, and Precedence Chapter-

# %%
# Block One
BIKE = True
CAR = True
TRAVEL_100_KM = BIKE or CAR

print(f"You have BIKE: {BIKE}")
print(f"You have CAR: {CAR}")
print(f"You can travel 100 KMs: {TRAVEL_100_KM}\n")


# Block Two
BIKE = True
CAR = False
TRAVEL_100_KM = BIKE or CAR

print(f"You have BIKE: {BIKE}")
print(f"You have CAR: {CAR}")
print(f"You can travel 100 KMs: {TRAVEL_100_KM}\n")

# Block Three
BIKE = False
CAR = True
TRAVEL_100_KM = BIKE or CAR

print(f"You have BIKE: {BIKE}")
print(f"You have CAR: {CAR}")
print(f"You can travel 100 KMs: {TRAVEL_100_KM}\n")

# Block Four
BIKE = False
CAR = False
TRAVEL_100_KM = BIKE or CAR

print(f"You have BIKE: {BIKE}")
print(f"You have CAR: {CAR}")
print(f"You can travel 100 KMs: {TRAVEL_100_KM}\n")

# %% [markdown]
# **EXAMPLE**:
# So above codes are repetetive. Now lets observe the below code which will give the same results as shown above but in avery less line of code. -

# %%
def travel_or_not(BIKE, CAR):
    TRAVEL_100_KM = BIKE or CAR

    print(f"You have BIKE: {BIKE}")
    print(f"You have CAR: {CAR}")
    print(f"You can travel 100 KMs: {TRAVEL_100_KM}\n")

travel_or_not(False, False)

travel_or_not(False, True)

travel_or_not(True, False)

travel_or_not(True, True)

# %% [markdown]
# **EXAMPLE**:
# Lets make it more concise using a for loop and remove the repetition-

# %%
def travel_or_not(BIKE, CAR):
    TRAVEL_100_KM = BIKE or CAR

    print(f"You have BIKE: {BIKE}")
    print(f"You have CAR: {CAR}")
    print(f"You can travel 100 KMs: {TRAVEL_100_KM}\n")
    
BIKE = [False, False, True, True]
CAR = [False, True,False, True]

for bike, car in zip(BIKE, CAR):
    travel_or_not(bike, car)

# %% [markdown]
# ### 7.2 Default Arguments
#
# **EXAMPLE**:
# Let's see a different varient of above code. You can also define a default value of the arguments which will be utilized when no argument is passed. as shown below -

# %%
def travel_or_not(BIKE=True, CAR=False):
    TRAVEL_100_KM = BIKE or CAR

    print(f"You have BIKE: {BIKE}")
    print(f"You have CAR: {CAR}")
    print(f"You can travel 100 KMs: {TRAVEL_100_KM}\n")


travel_or_not()

# %%
def travel_or_not(BIKE=True, CAR=False):
    TRAVEL_100_KM = BIKE or CAR

    print(f"You have BIKE: {BIKE}")
    print(f"You have CAR: {CAR}")
    print(f"You can travel 100 KMs: {TRAVEL_100_KM}\n")


travel_or_not(False, True) # overriding the default arguments value by passing our value

# %% [markdown]
# **EXAMPLE**:
# Here ```None``` gets printed if we try to print the ouput of the given function because it is not returning any value. Its just printing ther results.

# %%
result = travel_or_not(False, True)
print(f"\nresults:-\n{result}")

# %% [markdown]
# ### 7.3 Return statement
#
# **EXAMPLE**:
# In some cases you'd like to return some value from a function. So for that we use a return keyword to return the results as show below-

# %%
def travel_or_not(BIKE=True, CAR=False):
    TRAVEL_100_KM = BIKE or CAR

    print(f"You have BIKE: {BIKE}")
    print(f"You have CAR: {CAR}")
    return f"You can travel 100 KMs: {TRAVEL_100_KM}\n"


result = travel_or_not(False, True)
print(f"\nresults:-\n{result}")

# %% [markdown]
# **EXAMPLE**:
# You can also return multiple values as show below -

# %%
def travel_or_not(BIKE=True, CAR=False):
    TRAVEL_100_KM = BIKE or CAR

    return BIKE, CAR, TRAVEL_100_KM


result1, result2, result3 = travel_or_not(False, True)
print(f"You have BIKE: {result1}")
print(f"You have CAR: {result2}")
print(f"You can travel 100 KMs: {result3}\n")

# %% [markdown]
# ### 7.4 Variable length args
#
# **EXAMPLE**:
# At some point there may be chance that you don't know how many args that you should pass. Lets check the example below -

# %%
def branch_and_subjects_in_graduation(*args, branch):
    print(f"My branch was {branch}")
    return f"I liked these subjects in graduation {args}"

results = branch_and_subjects_in_graduation("Digital Image Processing", "Microprocessor", branch="Electronics engineering")
print(results)

# %%
def test(*args):
    print(args)
test(10,20,30,40,50)

# %%
def branch_and_subjects_in_graduation(*args, branch="Electronics engineering"):
    print(f"My branch was {branch}")
    return f"I liked these subjects in graduation {args}"

results = branch_and_subjects_in_graduation("Digital Image Processing", "Microprocessor")
print(results)

# %% [markdown]
# ### 7.5 Variable length keyword args
#
# **EXAMPLE**:
# Some times we need varying keyword arguments as shown below-

# %%
def marks_in_subjects_of_semester(**kwargs):
    print(kwargs)

marks_in_subjects_of_semester(Digital_Image_Processing = 78, Microprocessor= 79, Signals_and_systems=83)

# %%
def test1(**kwargs):
    print(kwargs)

# %%
test1(a=10,b=20,c=30,d=40)

# %%
A=[]
B=()

# %%
def marks_in_subjects_of_semester(**kwargs):
    for subject, marks in kwargs.items():
        print(f"Score in {subject} = {marks}")

marks_in_subjects_of_semester(Digital_Image_Processing = 78, Microprocessor= 79, Signals_and_systems=83)

# %% [markdown]
# ### 7.6 Functions inside functions -
# **EXAMPLE**:

# %%
def marks_in_subjects_of_semester(**kwargs):
    def total_marks(marks_list):
        return sum(marks_list)
    
    marks_list = list()
    for subject, marks in kwargs.items():
        marks_list.append(marks)
        print(f"Score in {subject} = {marks}")
    
    return total_marks(marks_list)

results = marks_in_subjects_of_semester(Digital_Image_Processing = 78, Microprocessor= 79, Signals_and_systems=83)

print(f"\ntotal marks obtained {results}")
# Out:
# Score in Digital_Image_Processing = 78
# Score in Microprocessor = 79
# Score in Signals_and_systems = 83
#
# total marks obtained 240

# %% [markdown]
# ### 7.7 Anonymous Function or Lambda Function
#
# **EXAMPLE**: Lets convert below example into a onliner or lambda function

# %% [markdown]
# ```python
# def travel_or_not(BIKE=True, CAR=False):
#     TRAVEL_100_KM = BIKE or CAR
#
#     print(f"You have BIKE: {BIKE}")
#     print(f"You have CAR: {CAR}")
#     return f"You can travel 100 KMs: {TRAVEL_100_KM}\n"
#
#
# result = travel_or_not(False, True)
# print(f"\nresults:-\n{result}")
# ```

# %%
BIKE=True
CAR=False

result = lambda BIKE, CAR: f"You can travel 100 KMs: {BIKE or CAR}\n"
print(f"\nresults:-\n{result(BIKE, CAR)}")

# %% [markdown]
# **EXAMPLE**
# Lets make a lambda function that returns power of an input no. It takes power and number as an input

# %%
number = 5
power = 3
result = lambda number, power: number**power

print(f"{number} to the power of {power} is {result(number, power)}")

# %% [markdown]
# ### 7.8 Scope of variables
# * Variables defined inside the function are known as Local variable
#
# * Global varaibles can be accessed anywhere in the script unlike local variable who's scope is defined within the function only.
#
# **EXAMPLE**

# %%
result = 0 # outside the scope of function

def divide(numerator, denominator):
    result = numerator//denominator # result inside the scope of function
    print(f"result after division inside the function: {result}")

numerator = 625
denominator = 5
divide(numerator, denominator)

print(f"result after division outside the function: {result}")

# %% [markdown]
# ### 7.9 Docstring
#
# ```python
# def function():
#     """
#     This is docstring of the function.
#     """
#     pass
# ```
# **EXAMPLE**

# %%
def find_power(number, power):
    """This function returns the power of the number

    Args:
        number (int): insert any integer value
        power (int): insert any integer value

    Returns:
        integer: power of number
    """
    return number**power

number = 5
power = 3
result = find_power(number, power)

print(f"{number} to the power of {power} is {result}")

# %%
# This prints the docstring.
# Its very good practice to write the docstring of very important function
# It imroves code readabilty
help(find_power)

# %% [markdown]
# FUNCTIONS
#
# ## ----------------------------------------------------------------------

# %% [markdown]
# code re-usability.

# %% [markdown]
# To create and use a function we have to take 2 steps:
#
#
# Function Definition: Creating or writing the body of a function is called defining it. It contains the set of statements we want to run , when the function execute.
#
# Function Call: A function never runs automatically . So to execute it’s statements we must call it

# %%
def function_name(param1,param2):
    statement(s)

# %% [markdown]
# ### About Return Statement

# %% [markdown]
# - Return value
#
# - Return multiple value
#
# - it will stop the execution from that line itself

# %%
def add(x,y):
    a=x
    b=y
    c=a+b
    #print(c)
    mul=x*y
    print(mul)
    return c

# %%
add(10,20)

# %% [markdown]
# #### Parameter vs Argument

# %% [markdown]
# In Python , a function can have 4 types of arguments:
#
# Positional Argument
#
# Keyword Argument
#
# Default Argument
#
# Variable Length Argument

# %% [markdown]
# if number of argument is not matching with number of parameter then we will get a type error.

# %% [markdown]
# #### Positional Argument

# %%
def attach(s1,s2):
    s3=s1+s2
    print("Joined String is:",s3)

# %%
attach("Good","Evening")

# %%
def grocery(name,price):
    print("Item is",name,"It's price is",price)

# %%
grocery("Bread",20)

# %%
grocery(150,"Butter")

# %% [markdown]
# #### Keyword Argument

# %%
def grocery(name,price):
    print("Item is",name,"It's price is",price)

# %%
grocery('bread',200)

# %%
grocery(200,'bread')

# %%
grocery(name="Bread",price=20)

# %%
grocery(price=150,name="Butter")

# %%
### A positional argument can never follow a keyword argument i.e. the keyword argument should always appear after positional argument

###For example:

# %%
def display(num1,num2):
    # some code
    pass

# %%
display(num1=10,15)

# %%
display(15,num1=10)

# %%
display(15,num2=10)

# %%
def display(10,num2=15):
    pass

# %%
Now if we call the above function as:



Then it will be correct. But if we call it as:



Then it will be a Syntax Error

# %% [markdown]
# ### Default Argument

# %% [markdown]
# For some functions, we may want to make some parameters optional and use default values in case the user does not want to provide values for them.
#
# This is done with the help of default argument values.
#
# We can specify default argument values for parameters by appending to the parameter name in the function definition the assignment operator (=) followed by the default value.

# %% [markdown]
# #Syntax:
# def function_name(paramname1=value,paramname2=value):
#     # function body
#     pass

# %%
def greet(name,msg="Good Morning"):
    print("Hello",name,msg)

# %%
greet("Sunny")

# %%
greet("sunny","How are you?")

# %% [markdown]
# A function can have any number of default arguments but t once we have a default argument, all the arguments to it’s right must also have default values.
#
#
# This means to say, non-default arguments cannot follow default arguments.

# %%
def greet(msg = "Good morning!", name):
    pass

# %%
For example:  if we had defined the function header above as:

def greet(msg = "Good morning!", name):

Then we would have got the following SyntaxError

# %%
def show(a=10,b=20,c=30):
    print(a,b,c)

# %% [markdown]
# ### Excercise
#
# Write a function called cal_area( ) using default argument concept which accepts radius and pi as arguments and calculates and displays area of the Circle. The value of pi should be used as default argument and value of radius should be accepted from the user

# %% [markdown]
# ### Function or Method Overloading

# %% [markdown]
# Method Overloading is an example of Compile time polymorphism.In this, more than one method of the same class shares the same method name having different parameters.If a class has multiple methods having same name but different in parameters, it is known as Method Overloading.
#
# Note: Python does not support method overloading. We may overload the methods but can only use the latest defined method.

# %%
def addnos(a,b):
    c=a+b
    return c

# %%
def addnos(a,b,c):
    d=a+b+c
    return d

# %%
def addnos(a,b,c,d):
    d=a+b+c+d
    return d

# %%
addnos(10,20,30,40)

# %%
print(addnos(10,20))

# %%
print(addnos(10,20,30))

# %% [markdown]
# The error occurred because Python does not support Function or Method Overloading
#
# Moreover Python understands the latest definition of a function addnos( ) which takes 3 arguments
#
# Now since we passed 2 arguments only , the call generated error because Python tried to call the method with 3 arguments

# %% [markdown]
# ### Variable Length Arguments

# %% [markdown]
# The solution to this problem is a technique called variable length arguments
#
#
#
#
# In this technique , we define the function in such a way that it can accept any number of arguments from 0 to infinite

# %%
def test(**sunny):
    print(sunny)
    print(type(sunny))

# %%
test(10)

# %%
test(10,20)

# %%
test(10,20,30)

# %%
def addnos(*a):
    sum =0
    for x in a:
        sum=sum+x
    return sum

# %%
print(addnos(10,20))
print(addnos(10,20,30)) 
print(addnos(10,20,30,40))

# %%
type(10)

# %%
type((10))

# %%
type((10,))

# %% [markdown]
# ### Method Overriding

# %% [markdown]
# Method overriding is an ability of any object-oriented programming language that allows a subclass or child class to provide a specific implementation of a method that is already provided by one of its super-classes or parent classes.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Defining parent class
class Animal():
      
    # Constructor
    def __init__(self):
        self.value = "Inside Parent"
          
    # Parent's show method
    def show(self):
        print(self.value)
    
    def eat(self):
        pass

# %%
# Defining child class
class Dog(Animal):
      
    # Constructor
    def __init__(self):
        self.value = "Inside Child"
          
    # Child's show method
    def show(self):
        print(self.value)
    
    def eat(self):
        pass

# %%
# Driver's code
obj1 = Parent()
obj2 = Child()
  
obj1.show()
obj2.show()

# %% [markdown]
# ### Exercise
# Write a function called find_largest( ) which accepts multiple strings as argument and returns the length of the largest string

# %%
### A function cannot have 2 variable length arguments. So the following is wrong:

def addnos(*a,*b):
    pass

# %%
#If we have any other argument along with variable length argument , then it should be set before the variable length argument
def addnos(n,*a):
    sum =n
    print(n)
    print(a)
    for x in a:
        sum=sum+x
    return sum

# %%
print(addnos(10,20,30))

# %%
print(addnos(10,20,30,40))

# %%
#If we set the other argument used with variable length argument , after the variable length argument then while calling it , we must pass it as keyword argument

def addnos(*a,n):
    print(a)
    print(n)
    sum =n
    for x in a:
        sum=sum+x
    return sum

# %%
addnos(20,30,n=40)

# %%
print(addnos(20,30,n=10))

# %%
print(addnos(20,30,40,n=10))

# %% [markdown]
# ## User Defined Functions
#
# Variable Scope
#
# Local Scope
#
# Global Scope
#
# Argument Passing

# %%
Local : Inside a function body
Enclosing: Inside an outer function’s body . We will discuss it later
Global: At the module level
Built In: At the interpreter level

# %%
s = "I love Python"#global variable
def f(): 
    print(s) 
f()

# %%
indentation

def test():
    ajcjc
    hjafhs
    hakfshks
kjgjsdsjkas

# %%
def f(): 
    print(s) 
s = "I love Python"# global or local?
f()

# %%
def f():
    print(p)
f()
p="I love Python"

# %%
def f():
    s="I love Python"#local variable
    print(s)
f()

# %%
def f():
    s1="I love Python"#local variable
    print(s1)
f()
print(s1)

# %%
s2="I love Python"
def f():
    s2="I love C"
    print(s2)
    print(id(s2))
f()
print(s2)
print(id(s2))

# %%
def f():
    global p1
    p1="I love C"
    print(p1)
    #print(id(p))
f()
print(p1)

# %%
print(p)

# %%
s1="I love Python"
def f():
    s1="I love C"
    print(s1)
    print(id(s1))
f()
print(s1)
print(id(s1))
# Out:
# I love C
# 2046596301936
# I love Python
# 2046596301616

# %%
s="I love Python"
def f():
    global s
    s="I love C"
    print(s)
    print(id(s))
f()
print(s)
print(id(s))
# Out:
# I love C
# 2046596303984
# I love C
# 2046596303984

# %%
s="I love Python"

# %%
def f():
    global s
    print(s)
    s="I love C"
    print(s)
f()
print(s)

# %%
a=1
def f():
    print ('Inside f() : ', a)
def g():    
    a = 2
    print ('Inside g() : ',a)
def h():    
    global a
    a = 3
    print ('Inside h() : ',a)
 
print ('global : ',a)
f()
print ('global : ',a)
g()
print ('global : ',a)
h()
print ('global : ',a)

# %% [markdown]
# Lambda Function
#
# The map( ) Function
#
# The filter( ) Function
#
# Using map( ) and filter( ) with Lambda Expressions

# %% [markdown]
# ### What is Anonymous Function

# %% [markdown]
# An anonymous function is a function that is defined without a name

# %% [markdown]
# ### Difference between anonymous function and normal function

# %% [markdown]
# While normal functions are defined using the def keyword, we define anonymous functions using the lambda keyword.

# %% [markdown]
# ### Syntax: lambda [arg1,arg2,..]:[expression]

# %% [markdown]
# lambda is a keyword/operator and can have any number of arguments.
#
# But it can have only one expression.
#
# Python evaluates the expression and returns the result automatically

# %% [markdown]
# An expression here is anything that can return some value.
#
# The following items qualify as expressions.
#
# Arithmetic operations like a+b and a**b
#
# Function calls like sum(a,b)
#
# A print statement like print(“Hello”)

# %% [markdown]
# Assignment statements cannot be used in lambda , because they don’t return anything, not even None (null).
#
# Simple things such as mathematical operations, string operations etc. are OK in a lambda.
#
# Function calls are expressions, so it’s OK to put a function call in a lambda, and to pass arguments to that function.
#
# Even functions that return None, like the print function in Python 3, can be used in a lambda.
#
# Single line if – else is also allowed as it also evaluates the condition and returns the result of true or false expression

# %%
#Suppose, we want to make a function which will calculate sum of two numbers.

#In normal approach we will do as shown below:


def add(a,b): 
    return a+b

# %%
add(10,20)
# Out:
# 30

# %%
#In case of lambda function we will write it as:

print((lambda a,b:a+b)(10,20))
# Out:
# 30

# %% [markdown]
# A very common doubt is that when we can define our functions using def keyword , then why we require lambda functions ?
#
# The most common use for lambda functions is in code that requires a simple one-line function, where it would be an overkill to write a complete normal function.
#
# We will explore it in more detail when we will discuss two very important functions in Python called map( ) and filter( )

# %% [markdown]
# There are 2 ways to use a Lambda Function.
#
#
# - Using it anonymously in inline mode
#
# - Using it by assigning it to a variable

# %%
#Using it as anonymous function

print((lambda a,b: a+b)(2,3))

# %%
#Using it by assigning it to a variable

sum=lambda a,b: a+b

# %%
print(sum(2,3))
# Out:
# 5

# %%
print(sum(5,9))
# Out:
# 14

# %% [markdown]
# What is happening in this code ?
#
# The statement lambda a,b:a+b ,
#
# is creating a FUNCTION OBJECT
#
# and returning that object . The
#
# variable sum is referring to that
#
# object. Now when we write sum(2,3), it behaves like function call

# %%
sum=lambda a,b: a+b

print(type(sum))
print(sum)

# %%
squareit=lambda a: a*a

print(squareit(25))
print(squareit(10))

# %%
import math

squr=lambda a:math.sqrt(a)

# %%
squr(25)
# Out:
# 5.0

# %%
st=lambda str:str[0]

# %%
st("sunny")
# Out:
# 's'

# %%
iseven=lambda n: n%2==0

# %%
print("10 is even :",iseven(11))
# Out:
# 10 is even : False

# %%
print("7 is even:",iseven(7))

# %%
#Write a lambda function that accepts 2 arguments and returns the greater amongst them
maxnum=lambda a,b: a if a>b else b

# %%
print("max amongst 10 and 20 :",maxnum(10,20))
# Out:
# max amongst 10 and 20 : 20

# %%
print("max amongst 15 and 5 :",maxnum(15,5))
# Out:
# max amongst 15 and 5 : 15

# %% [markdown]
# ### map() function in python

# %%
#map() is a function which takes two arguments:
r = map(func, iterable)

# %% [markdown]
# The first argument func is the name of a function and the second argument  , iterable  ,should be a sequence (e.g. a list , tuple ,string etc) or anything that can be used with for loop.
#
# map() applies the function func to all the elements of the sequence iterable

# %% [markdown]
# ### To understand this , let’s solve a problem

# %%
#Suppose we want to define a function called square( ) that can accept a number as argument and returns it’s square.

#The definition of this function would be:

def square(num):
    return num**2

# %%
square(5)
# Out:
# 25

# %%
square(25)
# Out:
# 625

# %%
#Now suppose we want to call this function for the following list of numbers:

mynums=[1,2,3,4,5]

# %%
#One way to do this , will be to use a for loop 

mynums=[1,2,3,4,5]
for x in mynums:
    print(square(x))
# Out:
# 1
# 4
# 9
# 16
# 25

# %%
def square(num):
    return num**2
mynums=[1,2,3,4,5]
for x in mynums:
    print(square(x))
# Out:
# 1
# 4
# 9
# 16
# 25

# %%
<map at 0x1b3e7ae1880>

# %% [markdown]
# Another way to solve the previous problem is to use the map( ) function .
# The map( ) function will accept 2 arguments from us.
#
# The first argument will be the name of the function square
#
# The second argument will be the list mynums.
#
# It will then apply the function square on every element of mynum and return the corresponding result as map object

# %%
def square(num):
    return num**2
mynums=(1,2,3,4,5)

# %%
print(list(map(square,mynums)))
# Out:
# [1, 4, 9, 16, 25]

# %%
def square(num):
    return num**2

mynums=[1,2,3,4,5]
result=map(square,mynums)
print(result)

# %% [markdown]
# As we can observe , the return value of map( ) function is a map object
#
# To convert it into actual numbers we can pass it to the function list( )

# %%
def square(num):
    return num**2

mynums=[1,2,3,4,5]
result=map(square,mynums)

# %%
result

# %%
sqrnum=list(result)

# %%
print(sqrnum)
# Out:
# [1, 4, 9, 16, 25]

# %%
def square(num):
    return num**2


mynums=[1,2,3,4,5]
# we can club the 2 lines in 1 line

sqrnum=list(map(square,mynums))

print(sqrnum)

# %%
#To make it even shorter we can directly pass the list( ) function to 
#the function print()
def square(num):
    return num**2

mynums=[1,2,3,4,5]
print(list(map(square,mynums)))

# %%
#In case we want to iterate over this list , then we can use for loop
def square(num):
    return num**2

mynums=[1,2,3,4,5]
for x in map(square,mynums):
    print(x)

# %% [markdown]
# Write a function called inspect( ) that accepts a string as argument and returns the word EVEN if the string is of even length and returns it’s first character if the string is of odd length
#
# Now call this function for first 3 month names

# %%
def inspect(mystring):
    if len(mystring)%2==0:
        return "EVEN"
    else:
        return mystring[0]

months=["January","February","March"]
print(list(map(inspect,months)))
# Out:
# ['J', 'EVEN', 'M']

# %% [markdown]
# ### filter() function in python

# %% [markdown]
# Another way to solve the previous problem is to use the filter( ) function .
#
#
# The flter( ) function will accept 2 arguments from us.
#
# The first argument will be the name of the function check_even
#
# The second argument will be the list mynums.
#
# It will then apply the function check_even on every element of mynum and if check_even returned True for that element then filter( ) will return that element as a part of it’s return value otherwise that element will not be returned

# %%
num=7

# %%
num%2
# Out:
# 1

# %%
def check_even(num):
    return num%2!=0

# %%
check_even(7)
# Out:
# True

# %%
mynums=[1,2,3,4,5,6]

# %%
value=filter(check_even,mynums)

# %%
list(value)
# Out:
# [1, 3, 5]

# %%
print()
# Out:
# <filter object at 0x000001F01B38DA00>

# %% [markdown]
# As we can observe , the return value of filter( ) function is a  filter object
#
# To convert it into actual numbers we can pass it to the function list( )

# %%
def check_even(num):
    return num%2==0

mynums=[1,2,3,4,5,6]
print(list(filter(check_even,mynums)))
# Out:
# [2, 4, 6]

# %%
#In case we want to iterate over this list , then we can use for loop 
#as shown below:
def check_even(num):
    return num%2==0

mynums=[1,2,3,4,5,6]
for x in filter(check_even,mynums):
    print(x)
# Out:
# 2
# 4
# 6

# %%
def f1(num):
    return num*num

mynums=[1,2,3,4,5]
print(list(filter(f1,mynums)))
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# Ideally , the function passed to filter( ) should return a boolean value. But if it doesn’t return boolean value , then whatever value it returns Python converts it to boolean . In our case for each value in mynums the return value will be it’s square which is a non-zero value and thus assumed to be True. So all the elements are returned by filter()

# %%
def f1(num):
    return num%2

# %%
f1(11)
# Out:
# 1

# %%
True+False
# Out:
# 1

# %%
def f1(num):
    print(num%2)
    #return num%2

mynums=[1,2,3,4,5]
print(list(filter(f1,mynums)))
# Out:
# 1
# 0
# 1
# 0
# 1
# []

# %%
filter(f1,mynums)

# %% [markdown]
# For every even number the return value of the function f1( ) will be 0 which is assumed to be False and for every odd number the return value will be 1 which is assumed to be True . Thus filter( ) returns only those numbers for which f1( ) has returned 1.

# %%
def f1(num):
    print("Hello")

# %%
f1(5)
# Out:
# Hello

# %%
mynums=[1,2,3,4,5]
print(list(filter(f1,mynums)))
# Out:
# Hello
# Hello
# Hello
# Hello
# Hello
# []

# %% [markdown]
# Hello is displayed 5 times because the filter( ) function has called f1( ) function 5 times. Now for each value in mynums , since f1( ) has not returned any value , by default it’s return value is assumed to be None which is a representation of False. Thus filter( ) returned an empty list.

# %%
def f1(num):
    pass

mynums=[1,2,3,4,5]
print(list(filter(f1,mynums)))
# Out:
# []

# %% [markdown]
# For each value in mynums , since f1( ) has not returned any value , by default it’s return value is assumed to be None which is a representation of False. Thus filter( ) returned an empty list.

# %%
def f1():
    pass

mynums=[1,2,3,4,5]
print(list(filter(f1,mynums)))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-804ed006219b> in <module>
#       3
#       4 mynums=[1,2,3,4,5]
# ----> 5 print(list(filter(f1,mynums)))
#       6
#
# TypeError: f1() takes 0 positional arguments but 1 was given

# %% [markdown]
# The function filter() is trying to call f1( ) for every value in the list mynums. But since f1( ) is a non-parametrized function , this call generates TypeError

# %%
def f1():
    pass

mynums=[]
print(list(filter(f1,mynums)))

# %%
def f1(num):
    return num%2

mynums=[1,2,3,4,5]
print(list(map(f1,mynums)))
# Out:
# [1, 0, 1, 0, 1]

# %%
def f1(num):
    return num%2

mynums=[1,2,3,4,5]
print(list(filter(f1,mynums)))
# Out:
# [1, 3, 5]

# %% [markdown]
# For every even number the return value of the function f1( ) will be 0 and for every odd number the return value will be 1. Thus map( ) has returned a list containing 1 and 0 for each number in mynums based upon even and odd.

# %%
def f1(num):
    pass

mynums=[1,2,3,4,5]
print(list(map(f1,mynums)))
# Out:
# [None, None, None, None, None]

# %% [markdown]
# Since f1( ) is not returning anything , so it’s return value by default is assumed to be None  and because map( ) has internally called f1 () 5 times , so the list returned contains None 5 times

# %%
def f1():
    pass

mynums=[]
print(list(map(f1,mynums)))
# Out:
# []

# %% [markdown]
# The best use of Lambda Expression is to use it with map( ) and filter( ) functions
#
#
#
#
# Recall that the keyword lambda creates an anonymous function and returns it’s address.

# %% [markdown]
# So , we can pass this lambda expression as first argument to map( ) and filter() functions , since their first argument is the a function object reference
#
#
# In this way , we wouldn’t be required to specially create a separate function using the keyword def

# %%
def square(num):
    return num**2

mynums=[1,2,3,4,5]
squrnum=list(map(square,mynums))
print(squrnum)
# Out:
# [1, 4, 9, 16, 25]

# %%
#To convert the above code using lambda ,we have to do 2 changes:

#Remove the function square( )

#Rewrite this function as lambda in place of first argument while calling the function map( )

# %%
map(lambda num: num*num,mynums)

# %%
#Following will be the resultant code:

mynums=[1,2,3,4,5]
sqrnum=list(map(lambda num: num*num,mynums))
print(sqrnum)
# Out:
# [1, 4, 9, 16, 25]

# %% [markdown]
# ### Exercise1

# %% [markdown]
# Write a lambda expression that accepts a string as argument and returns it’s first character
#
# Now use this lambda expression in map( ) function
# to work on for first 3 month names

# %%
list(map(lambda x:x[0],['bunny','sudhanshu','krish']))
# Out:
# ['b', 's', 'k']

# %%
months=["January","February","March"]
print(list(map(lambda mystring: mystring[0],months)))

# %% [markdown]
# ### Exercise2

# %% [markdown]
# Write a lambda expression that accepts a string as argument and returns the word EVEN if the string is of even length and returns it’s first character if the string is of odd length
#
# Now use this lambda expression in map( ) function
# to work on for first 3 month names

# %%
list(map(lambda x:"EVEN" if len(x)%2==0 else x[0],['bunny','sudhansh','krish']))
# Out:
# ['b', 'EVEN', 'k']

# %%
months=["January","February","March"]
print(list(map(lambda mystring: "EVEN" if len(mystring)%2==0 else 
mystring[0],months)))

# %% [markdown]
# ### Exercise3

# %% [markdown]
# Write a lambda expression that accepts a character as argument and returns True if it is a vowel otherwise False
#
# Now ask the user to input his/her name and display
# only the vowels in the name . In case the name does
# not contain any vowel display the message No vowels
# in your name

# %%
mynums=[1,2,3,4,5,6]
print(list(filter(lambda num:num%2==0 ,mynums)))
# Out:
# [2, 4, 6]

# %%
Write a lambda expression that accepts a character as argument and returns True if it is a vowel otherwise False

Now ask the user to input his/her name and display 
only the vowels in the name . In case the name does 
not contain any vowel display the message No vowels 
in your name

# %%
name=input("Enter your name:")
vowels=list(filter(lambda ch: ch in "aeiou" ,name))
if len(vowels)==0:
    print("No vowels in your name")
else:
    print("Vowels in your name are:",vowels)

# %%
def between(number, min=0, max=1000):
    return max > number > min

# Only returns number between 10 and 1000
filter(lambda x: between(x, min=10), range(10000))

# %%
a=42

# %%
b=42

# %%
c=42

# %%
id(a)
# Out:
# 140703981190208

# %%
id(b)
# Out:
# 140703981190208

# %%
id(c)
# Out:
# 140703981190208

# %%
a=43

# %%
id(a)
# Out:
# 140703981190240

# %%
id(b)
# Out:
# 140703981190208

# %%
id(c)
# Out:
# 140703981190208

# %%
b
# Out:
# 42

# %%
c
# Out:
# 42

# %%
a
# Out:
# 43

# %%
a=42

# %%
id(a)
# Out:
# 140703981190208

# %%
a=10

# %%
id(a)
# Out:
# 140703981189184

# %%
a=20

# %%
id(20)
# Out:
# 140703981189504

# %%
a=30

# %%
id(a)
# Out:
# 140703981189824

# %%
a="sunny"

# %%
b="sudhanshu"

# %%
a is b
# Out:
# False

# %%
id(a)
# Out:
# 2130760172912

# %%
id(b)
# Out:
# 2130793892016

# %%
a="ravi"

# %%
b="ravi"

# %%
a is b
# Out:
# True

# %%
id(a)
# Out:
# 2130794293872

# %%
id(b)
# Out:
# 2130794293872

# %%
a=[1,2,3,4,5]

# %%
id(a)
# Out:
# 2130794313536

# %%
type(a)
# Out:
# list

# %%
a[3]=7

# %%
a
# Out:
# [1, 2, 3, 7, 5]

# %%
id(a)
# Out:
# 2130794313536

# %%
a=42

# %%
id(a)
# Out:
# 140703981190208

# %%
a=43

# %%
id(a)
# Out:
# 140703981190240

# %%
tup=(1,2,3,4,5)

# %%
tup[0]=4
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-106-79950056ad54> in <module>
# ----> 1 tup[0]=4
#
# TypeError: 'tuple' object does not support item assignment

# %%
id(tup)
# Out:
# 2130761246416

# %%
tup=(787,87348,98734985)

# %%
id(tup)
# Out:
# 2130793806976

# %%
def test():
    print("this is new function")

# %%
test()
# Out:
# this is new function

# %%
test()+"sai krishna"

# Here we get error because test() doesn't return anything and it is none type.
# print function is none type
# Out:
# this is new function
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 test()+"sai krishna"
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'str'

# %%
type(test())
# Out:
# this is new function
# NoneType

# %%
# We are getting test function as none type.
# concatenation is not possible between a none type and a string.
# But what i have to do so that this works fine.

# %%
def test1():
    return "this is test1 function"

# %%
test1()
# Out:
# 'this is test1 function'

# %%
type(test1())
# Out:
# str

# %%
# now this function is string type and we can do now concatenation with the string for this function.

# %%
test1()+ " And i am learning functions bro "
# Out:
# 'this is test1 function And i am learning functions bro '

# %%
# now i am able to do concatenation because both are strings here .

# %%
def test3():
    return 123456

# %%
type(test3())
# Out:
# int

# %%
# If u r looking for primitive data type as a return from functions then we should use return keyword.
# Automatically python will return the datatype we write in function.

# None is different object. NoneType is different object.Null is different object in python.

# %%
def test4():
    return 2,[1,3,5],"sai",3

# %%
test4()
# Out:
# (2, [1, 3, 5], 'sai', 3)

# %%
# We can return multiple objects in a function while returning 
# if u see the output after calling test4() properly .We got outout in tuple .
# When we return multiple objects by default it will be considered as tuple.

# %%
type(test4())
# Out:
# tuple

# %%
b=test4()

# %%
b
# Out:
# (2, [1, 3, 5], 'sai', 3)

# %%
b[1]
# Out:
# [1, 3, 5]

# %%
test4()
# test4() function returns 4 objects.And i want to store each object in a seperate variable.
# A single function can return multiple objects.
# Out:
# (2, [1, 3, 5], 'sai', 3)

# %%
# in single line we can create multiple variables
a,b,c,d = 1,"sai",[2,4,6,8,10],2+3j

# %%
a
# Out:
# 1

# %%
b
# Out:
# 'sai'

# %%
c
# Out:
# [2, 4, 6, 8, 10]

# %%
d
# Out:
# (2+3j)

# %%
p,q,r,s=test4()
# i am storing each object in a different variable.

# %%
p
# Out:
# 2

# %%
q
# Out:
# [1, 3, 5]

# %%
r
# Out:
# 'sai'

# %%
s
# Out:
# 3

# %%
p,q,r,s,t=test4()
# We get error because test4() function returns only 4 objects but we gave 5 variables here.
#Even if we observe error it says not enough values to unpack .
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 p,q,r,s,t=test4()
#
# ValueError: not enough values to unpack (expected 5, got 4)

# %%
# so to avoid this type of errors we can store the output in a single variable where tuple gets created
# with multiple objects like b=test4()  and the value of b is (2, [1, 3, 5], 'sai', 3) .In this way we can do .

# %%
# we can write complex logics inside the functions.

# %%
# we can perform operations inside the function.
def test5():
    
    a=6*7/6
    return a

# %%
test5()
# Out:
# 7.0

# %%
def triangle(n):
    """
    this is dynamic code for creating a traingle.
    we have to input a integer and we get triangle as a output 
    after executing the function.
    """
    for i in range(n):
        for j in range(i):
            print("*",end=" ")
        print("\r")

# %%
triangle(5)
# Now inside traingle function keep pointer and press shift and tab then u will see the docstring for the traingle function.
# If we want to write docstring for any function then just write it using inside triple quotes inside a function.
# Out:
# *
# * *
# * * *
# * * * *

# %%
help(triangle)
# help function gives the docstring of a function.
# help function works for custom function and in-built functions also.
# Out:
# Help on function triangle in module __main__:
#
# triangle(n)
#     this is dynamic code for creating a traingle.
#     we have to input a integer and we get triangle as a output
#     after executing the function.

# %%
# this is a single line comment

"""
this is multiline comments.
python compiler donot execute the comments.

"""
# if we write single or multiline comments in the code then those will be ignored.
# but if we write single or multiline comments inside the function then it will become DocString.
# Out:
# '\nthis is multiline comments.\npython compiler donot execute the comments.\n\n'

# %%
# Make sure u write the code as a function with docstring included everytime.
# this is the standard procedure.

# %%
# primitive element means integer,string,list,tuple,set,float,complex.

# %% [markdown]
# ![Screenshot%20%2844%29.png](attachment:Screenshot%20%2844%29.png)

# %%
# These are the questions.

# %%
#Question1
def length(n):

    count=0
    for i in n:
        count+=1
    return count

# %%
length("sudhanshu")
# Out:
# 9

# %%
# Question 2

def indexing(a):
    count=0
    for i in a:
        print(i,"index is",count)
        count+=1
        
        
# primitive element means integer,string,list,tuple,set,float,complex.

# %%
indexing([1,2,3,4,5,6,7,8])
# Out:
# 1 index is 0
# 2 index is 1
# 3 index is 2
# 4 index is 3
# 5 index is 4
# 6 index is 5
# 7 index is 6
# 8 index is 7

# %%
indexing("saikrishna")
# Out:
# s index is 0
# a index is 1
# i index is 2
# k index is 3
# r index is 4
# i index is 5
# s index is 6
# h index is 7
# n index is 8
# a index is 9

# %%
indexing({1,2,3,4,5,6,7,8})
# Out:
# 1 index is 0
# 2 index is 1
# 3 index is 2
# 4 index is 3
# 5 index is 4
# 6 index is 5
# 7 index is 6
# 8 index is 7

# %%
# Question 3

def fun1(d):
    l=[]
    for i in d.values():
        if type(i)== dict:
            for j in i.values():
                if type(j)==list :
                    l.extend(j)
                if type(j)==tuple :
                    l.extend(j)
                if type(j)==set :
                    l.extend(j)
                if type(j)==str :
                    l.append(j)
                if type(j)==int or type(j)==float or type(j)==complex:
                    l.append(j)
                    
        elif type(i)==int or type(i)==float or type(i)==complex:
            l.append(i)
                
        elif type(i)==list :
            l.extend(i)
            
        elif type(i)==tuple :
            l.extend(i)
            
        elif type(i)==set :
            l.extend(i)
        
        elif type(i)==str:
            l.append(i)
            
    return l

# %%
a={"first":1,"second":[1,2],"third":(3,4),"fourth":{5,6},"fifth":1.2,"sixth":5+4j,"seventh":{
  "name" : "Email","year" : 2004  
}
  }
fun1(a)
# Out:
# [1, 1, 2, 3, 4, 5, 6, 1.2, (5+4j), 'Email', 2004]

# %%
# Question 4

def fun2(a):
    return a**2

def fun3(b):
    return b+2

# %%
fun2(fun3(6))
# Out:
# 64

# %%
# Question 5

def fun(*kargs):
    result=[]
    for i in kargs:
        result.extend(i)
    return result

# %%
fun([1,2],[3,4])
# Out:
# [1, 2, 3, 4]

# %%
fun([1,2,3,5,6],[3,5,4,3,2,1],[45],[50,51])
# Out:
# [1, 2, 3, 5, 6, 3, 5, 4, 3, 2, 1, 45, 50, 51]

# %%
# Question 6

def funct(a):
    if type(a)==list:
        
        count=0
        for i in a:
            print("index of ",i,"is ",count)
            count+=1

# %%
funct([1,3,5,7,8,9,10])
# Out:
# index of  1 is  0
# index of  3 is  1
# index of  5 is  2
# index of  7 is  3
# index of  8 is  4
# index of  9 is  5
# index of  10 is  6

# %%
# Question 7
import os 
os.listdir()
# Out:
# ['-1.14-windows.xml',
#  '.android',
#  '.astropy',
#  '.atom',
#  '.BestSoft',
#  '.cache',
#  '.conda',
#  '.condarc',
#  '.config',
#  '.continuum',
#  '.emulator_console_auth_token',
#  '.gradle',
#  '.idlerc',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.Ld9VirtualBox',
#  '.matplotlib',
#  '.nbi',
#  '.node_repl_history',
#  '.ssh',
#  '.vscode',
#  '07 Functions_Revision.ipynb',
#  '20thvideo.ipynb',
#  '21stvideo.ipynb',
#  '23rdvideonotes.ipynb',
#  '3D Objects',
#  'addition.py',
#  'anaconda3',
#  'AndroidStudioProjects',
#  'ansel',
#  'AppData',
#  'Application Data',
#  'assignments practice.ipynb',
#  'cassandra notes 19th video',
#  'class 2 python.ipynb',
#  'Contacts',
#  'Cookies',
#  'Creative Cloud Files',
#  'data science',
#  "Database and it's related files",
#  'Documents',
#  'Downloads',
#  'echo',
#  'Favorites',
#  'file1.txt',
#  'file11.txt',
#  'file12.txt',
#  'file13.txt',
#  'file21.txt',
#  'file22.txt',
#  'file23.txt',
#  'first.ipynb',
#  'first.txt',
#  'firstdayofcodingjourney.ipynb',
#  'for loops while loop.ipynb',
#  'fourth.ipynb',
#  'glass.data',
#  'if else , for loop.ipynb',
#  'IntelGraphicsProfiles',
#  'krishna',
#  'Links',
#  'Local Settings',
#  'moduletesting.py',
#  'Music',
#  'My Documents',
#  'mydata.csv',
#  'mydata1.csv',
#  'NetHood',
#  'newmydata.csv',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{a2332f18-cdbf-11ec-8680-002248483d79}.TM.blf',
#  'NTUSER.DAT{a2332f18-cdbf-11ec-8680-002248483d79}.TMContainer00000000000000000001.regtrans-ms',
#  'NTUSER.DAT{a2332f18-cdbf-11ec-8680-002248483d79}.TMContainer00000000000000000002.regtrans-ms',
#  'ntuser.ini',
#  'OneDrive',
#  'oops.log',
#  'Postman',
#  'Postman Agent',
#  'practice assignments.ipynb',
#  'practice problem python basic.ipynb',
#  'PrintHood',
#  'python 1.ipynb',
#  'Python basic (3).ipynb',
#  'python basics class-I.ipynb',
#  'python codes',
#  'python ineuron .ipynb',
#  'python20thvideo',
#  'Recent',
#  'sai.txt',
#  'Saved Games',
#  'Searches',
#  'second.ipynb',
#  'second.txt',
#  'SendTo',
#  'Start Menu',
#  'task',
#  'Templates',
#  'test',
#  'test.txt',
#  'test1',
#  'test1.py',
#  'test1.txt',
#  'test5.py',
#  'test6.py',
#  'third.ipynb',
#  'train.pdf',
#  'Tuples , set , dict .ipynb',
#  'untitled',
#  'Untitled Folder',
#  'Untitled Folder 1',
#  'Untitled Folder 2',
#  'Untitled Folder 3',
#  'Untitled Folder 4',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
#  'Untitled2.ipynb',
#  'Untitled3.ipynb',
#  'untitled4',
#  'Untitled4.ipynb',
#  'Untitled5.ipynb',
#  'Untitled6.ipynb',
#  'updatedresult.csv',
#  'Videos',
#  '__pycache__']

# %%
os.listdir('C://Users//vamsi//OneDrive//Desktop')
# Out:
# ['Adobe Premiere Pro 2020.lnk',
#  'Atom.lnk',
#  'AWS',
#  'desktop.ini',
#  'HTML.DEMO',
#  'Microsoft Edge.lnk',
#  'MongoDBCompass.lnk',
#  'naresh i technologies',
#  'Postman Agent.lnk',
#  'Postman.lnk',
#  'secure-connect-test.zip',
#  'tailwind-sandbox-starter',
#  'Telegram.lnk',
#  'Topaz Video Enhance AI.lnk',
#  'Visual Studio Code.lnk',
#  'vs codes',
#  'Zoom.lnk']

# %%
# All files and sub-directories inside a directory can be retrieved using the listdir() method.
# This method takes in a path and returns a list of subdirectories and files in that path.
# If no path is specified, it returns the list of subdirectories and files from the current working directory.
# print(os.getcwd()) to know the current working directory.

# %%
# Question 8

import platform
my_system=platform.uname()

print("Node name is ",my_system.node)
print("System is",my_system.system)
print("Release",my_system.release)
print("Version",my_system.version)
print("Machine",my_system.machine)
print("Processor",my_system.processor)
# Out:
# Node name is  LAPTOP-UC0STVNH
# System is Windows
# Release 10
# Version 10.0.22631
# Machine AMD64
# Processor Intel64 Family 6 Model 165 Stepping 2, GenuineIntel

# %%
# Question 9

import datetime
x=datetime.datetime.now()
print(x)
# Out:
# 2024-07-26 20:59:10.960990

# %%
# Question 10

from PIL import Image
img=Image.open('C:/Users/vamsi/OneDrive/Pictures/Screenshots/gopi.jpg')
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=407x201>

# %%
# !pip install Pillow
# to download pillow module for the first time.

# %%
# Question 11

def play_video(path):
    
    from os import startfile
    startfile(path)
    
play_video('C:\\Users\\vamsi\\Videos\\Videoder\\Tata Birla Madhyalo Laila Trim.mp4')

# %%
# Question 12

import shutil 

original= r"C:\Users\vamsi\OneDrive\Pictures\Screenshots\Screenshot (44).png"
target= r"C:\Users\vamsi\OneDrive\Desktop\naresh i technologies\Screenshot (44).png"
shutil.move(original,target)


# https://datatofish.com/move-file-python/
# useful article .
# Out:
# 'C:\\Users\\vamsi\\OneDrive\\Pictures\\Screenshots\\Screenshot (44).png'

# %%
# Question 13

import os 
os.system("shutdown /s /t 1")

# %%
# Question 14

# %%
# Question 15

# %%
# !pip install pypdf
# Out:
# Requirement already satisfied: pypdf in c:\users\vamsi\anaconda3\lib\site-packages (4.3.1)

# %%
# Question 16


from pypdf import PdfReader 
reader = PdfReader('C:\\Users\\vamsi\\train.pdf') 
page = reader.pages[0] 
print(page.extract_text())

# %%
# Question 17

# !pip install python-docx
# Out:
# Collecting python-docx
#   Downloading python_docx-1.1.2-py3-none-any.whl (244 kB)
#                                               0.0/244.3 kB ? eta -:--:--
#      ----                                  30.7/244.3 kB 640.0 kB/s eta 0:00:01
#      -------------------                    122.9/244.3 kB 1.2 MB/s eta 0:00:01
#      ------------------------------------   235.5/244.3 kB 1.8 MB/s eta 0:00:01
#      -------------------------------------- 244.3/244.3 kB 1.4 MB/s eta 0:00:00
# Requirement already satisfied: lxml>=3.1.0 in c:\users\vamsi\anaconda3\lib\site-packages (from python-docx) (4.9.2)
# Collecting typing-extensions>=4.9.0 (from python-docx)
#   Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Installing collected packages: typing-extensions, python-docx
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.6.3
#     Uninstalling typing_extensions-4.6.3:
#       Successfully uninstalled typing_extensions-4.6.3
# Successfully installed python-docx-1.1.2 typing-extensions-4.12.2

# %%
# Question 18

import os
c=os.listdir()
for i in c:
    a=i.split(".")
    if "docx" in a :
        print(i)
# Out:
# Assignment_1.docx
# Assignment_2 (1).docx
# Assignment_2.docx
# Assignment_3 (1).docx
# SaiKrishna Resume Accenture.docx
# testing.docx

# %%
# Question 19

import socket
hostname=socket.gethostname()
hostaddr=socket.gethostbyname(hostname)

print("hostname is ",hostname)
print("ipaddress is ",hostaddr)
# Out:
# hostname is  LAPTOP-UC0STVNH
# ipaddress is  192.168.1.39

# %%
# 14,15,16,17,20

# %%
def test1(*args):
    return args

# we can use any name instead of args for the variable name.args is not a reserved keyword.
*args means take multiple arguments.
*args - it is static .so we can pass any number of arguments.

# %%
test1(2,3,"sai",[1,5,7,8])
# Out:
# (2, 3, 'sai', [1, 5, 7, 8])

# %%
test1([1,4,5,6,7],(1,2,3,4),"sai",1,4,5)
# Out:
# ([1, 4, 5, 6, 7], (1, 2, 3, 4), 'sai', 1, 4, 5)

# %%
def func3(*sudh,a):
    return sudh,a

# %%
func3(1,2,3,4)
# Here we got error because func3 function cannot understand which value to consider as a.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 func3(1,2,3,4)
#
# TypeError: func3() missing 1 required keyword-only argument: 'a'

# %%
# To solve this issue we can specify the value of variable 'a' properly .
func3(1,2,3,4,a=5)
# Out:
# ((1, 2, 3, 4), 5)

# %%
#Now this is working properly .

# %%
def test4(*sai,a,b,c,d):
    return sai,a,b,c,d

# %%
test4(3,4,5,6,a=[1,2],b=(1,2),c={1,2},d={1:"sai",2:"krishna"})
# Out:
# ((3, 4, 5, 6), [1, 2], (1, 2), {1, 2}, {1: 'sai', 2: 'krishna'})

# %%
def tes1(a,*sai):
    return sai,a

# %%
tes1(1,2,"sai",a=123)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 tes1(1,2,"sai",a=123)
#
# TypeError: tes1() got multiple values for argument 'a'

# %%
def tes2(a,*sai):
    return a,sai

# %%
test2(12,13,14,a="ganesh")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 test2(12,13,14,a="ganesh")
#
# NameError: name 'test2' is not defined

# %%
# Let's understand the issue why we are getting error and how to resolve this error.

# %%
test1(1,2,3,"gun")
# Out:
# (1, 2, 3, 'gun')

# %%
test2()

# %%
# whenever we keep individual argument in the beginning then it is going to consider first dataset as
#  value of the indvidual argument.

#def tes1(a,*sai):
#    return sai,a
#test1(1,2,3,"gun")

# %%
def test5(a,*sudh,b,c):
    return a,sudh,b,c

# %%
test5("sai",1,2,3,4,5,6,6,7)
# we get error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 test5("sai",1,2,3,4,5,6,6,7)
#
# TypeError: test5() missing 2 required keyword-only arguments: 'b' and 'c'

# %%
test5("sai",1,2,3,4,b=5,c=6)
# this works completely fine because test5(a,*sudh,b,c) first argument by default it will acess first value. 
# And after static we have assigned the vaiable b and c with values directly.so this is working fine.
# Out:
# ('sai', (1, 2, 3, 4), 5, 6)

# %%
# Arguments always going to return tuples.

# %%
def quest(*args):
    l=[]
    for i in args:
        if type(i)==list:
            l.append(i)
    return l

# %%
quest([1,2,3,4],3,4,5,6,7)
# Out:
# [[1, 2, 3, 4]]

# %%
quest([1,2,3],[4,5,6])
# Out:
# [[1, 2, 3], [4, 5, 6]]

# %%
# *args - any number of arguments
# **kwargs - any number of arguments as key-value pairs.

# %%
def fun(**kwargs):
    return kwargs

# %%
fun(1,2,3,4,5)
# we got error here because we didnot gave key-value pairs.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 fun(1,2,3,4,5)
#
# TypeError: fun() takes 0 positional arguments but 5 were given

# %%
fun(a=10,b=20)
# Out:
# {'a': 10, 'b': 20}

# %%
# for double static - by default it is returning me the dictionary.
# for single static = by default it is returning me the tuple.

# %%
def testing1(a,**sai):
    return sai,a

# %%
testing1(45,b=2,c=3,d=4,e=5)
# Out:
# ({'b': 2, 'c': 3, 'd': 4, 'e': 5}, 45)

# %%
# by default variable 'a' will take first argument .

# %%
def testing2(a,**kwargs,*args):
    return a,kwargs,args
# Out:
#   Cell In[4], line 1
#     def testing2(a,**kwargs,*args):
#                             ^
# SyntaxError: arguments cannot follow var-keyword argument

# %%
# this will give error because we cannot use single static after double static.
# Here a is positional argument ,kwargs is double static and args is single static.

# %%
def testing3(a,*args,**kwargs):
    return a,args,kwargs

# %%
# now we dont get any error because we can use double static after single static.

# %%
testing3(33,1,5,6,7,8,9,p=29,q=23,r=26)
# Out:
# (33, (1, 5, 6, 7, 8, 9), {'p': 29, 'q': 23, 'r': 26})

# %%
'''
testing3(33,1,5,6,7,8,9,p=29,q=23,r=26)
testing3(a,*args,**kwargs) here variable 'a' is considered as positional arguments and then remaining values are considered
as values till the keyvalue pairs comes.And then remaining considered as key-value pairs.

'''
# Out:
# "\ntesting3(33,1,5,6,7,8,9,p=29,q=23,r=26)\ntesting3(a,*args,**kwargs) here variable 'a' is considered as positional arguments and then remaining values are considered\nas values till the keyvalue pairs comes.And then remaining considered as key-value pairs.\n\n"

# %% [markdown]
# # Anonymous function

# %%
# function without name is called anonymous function.

# %%
# Anonymous functions in Python are also known as lambda functions.

# %%
# Syntax for lamda function  creation 
# lambda parameter(s) : expression
# lambda is reserved keyword.
# A lambda function is created using the lambda keyword.

# %%
lambda a,b : a*b
# The code above simply returns a lambda object in the console.
# Out:
# <function __main__.<lambda>(a, b)>

# %%
# Note that the function has no name. We assigned the lambda function to a variable

# %%
c=lambda a,b : a*b
# we are just storing this function in a simple normal variable.

# %%
c(23,45)
# Out:
# 1035

# %%
# lambda functions can be written in one line.

# %%
# we create lambda function for small operations .
# for complex functions then we have to use normal function .

# %%
# you can use a lambda function when you need a function that'll be used just once.

# %%
lambda x : [i for i in x]
# Out:
# <function __main__.<lambda>(x)>

# %%
s=lambda x : [i for i in x]

# %%
s([1,2,3,4,5,6])
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
a=50
def test16(c,d):
    return c*d

# %%
test16(a,50)
# variable 'a' is present outside the function.
# variable 'c' will be holding the value of 'a' so value of 'c' is 10.
# Out:
# 2500

# %%
a=10
def test16(c,d):
    a=5
    return c*d

# %%
test16(a,50)
# Out:
# 500

# %%
a=10
def test16(c,d):
    c=5
    return c*d

# %%
test16(a,50)
# Internally inside the function we are reassigning the value of 'c'
#  here again c is becoming 5.
# Out:
# 250

# %%
test16(10,50)
# here again c is becoming 5.
# Out:
# 250

# %%
c=10
def test16(c,d):
    c=5
    return c*d

# %%
test16(10,50)
# Out:
# 250

# %%
c
# global value of c will be printed here.
# local variable will not present outside the function.
# Out:
# 10

# %% [markdown]
# # Iterator,Iterable

# %%
a=32
for i in a:
    print(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 a=32
# ----> 2 for i in a:
#       3     print(i)
#
# TypeError: 'int' object is not iterable

# %%
a="sai"
for i in a:
    print(i)
# Out:
# s
# a
# i

# %%
# String is an iterable object whereas integer is not iterable object.

# %%
next(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 next(a)
#
# TypeError: 'str' object is not an iterator

# %%
# next is a function which will extract one element at a time if object is iterator.

# %%
# string is not iterator

# %%
#what is the difference between iterable and iterator ?

'''
if object is holding a values and if we can acess elements  with the help of indexing then it is called as
iterable object by default.

String is iterable object and for loop is trying to create string as iterator for example.
next is a function which will extract one element at a time if object is iterator.
And next("sai")gives error saying 'str' object is not an iterator.
so string is not iterator.

'''
# Out:
# '\nif object is holding a values and if we can acess elements  with the help of indexing then it is called as\niterable object by default.\n\nString is iterable object and for loop is trying to create string as iterator for example.\nnext is a function which will extract one element at a time if object is iterator.\nAnd next("sai")gives error saying \'str\' object is not an iterator.\nso string is not iterator.\n\n'

# %%
# String is iterable but not iterator.And by using iter function we can convert string from iterable to iterator.

# %%
d="vamsi"
next(d)

# if we apply next function directly to a string then we get error.Because string is not iterator.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 2
#       1 d="vamsi"
# ----> 2 next(d)
#
# TypeError: 'str' object is not an iterator

# %%
s="krishna"

# %%
iter(s)

# %%
# iter function will be able to convert iterable into iterator
# string is iterable so iter function will convert string from iterable to iterator
# we can acess individual elements only if it is available in the form of iterator.

# %%
b=iter(s)

# %%
next(b)
# Out:
# 'k'

# %%
# as we converted string into iterator we are able to acess individual elements one by one.

# %%
next(b)
# Out:
# 'r'

# %%
next(b)
# Out:
# 'i'

# %%
j="chandra"
for i in j:
    print(i)
    
    
'''
By default string is iterable object but for loop internally converting iterable to iterator using iter() and using next()
for loop is able to print all the individual elements.
This is how for loop internally works in the case of strings .

'''
# Out:
# c
# h
# a
# n
# d
# r
# a

# %%
# without even using for loop we can acess individual elements of string by converting iterable variable to iterator using
# iter function .

j="chandra"
b=iter(j)
next(b)
# Out:
# 'c'

# %%
next(b)
# Out:
# 'h'

# %%
next(b)
# Out:
# 'a'

# %%
next(b)
# Out:
# 'n'

# %%
next(b)
# Out:
# 'd'

# %%
next(b)
# Out:
# 'r'

# %%
next(b)
# Out:
# 'a'

# %%
next(b)
# we got error because all the elements are completed.so we get stop iterator error as all the elements are exhausted.
#But in case of for loop it identifies using length function len().
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 next(b)
#
# StopIteration:

# %%
l=[1,3,5,7,9]

# %%
next(l)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 next(l)
#
# TypeError: 'list' object is not an iterator

# %%
# List is iterable but not iterator.
# if something is iterable but not iterator then using iter()function we can convert iterable to iterator.
# we can use iter function only if that is iterable.

# %%
iter(45)
# Here we get eror because integer is not iterable object so we cannot use iter() for integers.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 iter(45)
#
# TypeError: 'int' object is not iterable

# %%
l
# Out:
# [1, 3, 5, 7, 9]

# %%
iter(l)
# we are able to convert list from iterable to iterator.

# %%
v=iter(l)

# %%
# we can convert list from iterable to iterator using iter() because list is iterable.

# %%
next(v)
# Out:
# 1

# %%
next(v)
# Out:
# 3

# %%
next(v)
# Out:
# 5

# %%
next(v)
# Out:
# 7

# %%
next(v)
# Out:
# 9

# %%
# list and string are iterable . so we can convert list or string to iterator using iter() and then using next() we can 
# acess elements one by one.

# %%
# Iterator simply means that in sequential manner one by one automatically my cursor is moving from one point to another 
# point .

# In automated way or with the help of pointers or with the help of next indexes if we are able to acess data that is called
# as iteration.

# %%
# all iterables are iterators

# %%
# dictionary is unordered collection.

# %%
# floating point numbers, complex numbers , boolean,integer are not iterable.so we cannot convert these 
# objects into iterators.

# %%
a=56

# %%
next(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 next(a)
#
# TypeError: 'int' object is not an iterator

# %%
# integer object is not an iterator . so let's see if it is iterable or not . If it is iterable then we can convert into 
# iterator using iter() function.But if integer is not iterable then we cannot convert integer into iterator object.

# %%
iter(56)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 iter(56)
#
# TypeError: 'int' object is not iterable

# %%
# this says 'int' object is not iterable.

# %%
t=(4,5,6,7)

# %%
next(t)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 next(t)
#
# TypeError: 'tuple' object is not an iterator

# %%
# tuples are not iterators

# %%
iter(t)

# %%
# so this is iterable object by default .And we can convert tuple into iterator object by using iter() function.

# %%
x=iter(t)

# %%
next(x)
# Out:
# 4

# %%
next(x)
# Out:
# 5

# %%
next(x)
# Out:
# 6

# %%
next(x)
# Out:
# 7

# %%
# so in this way we can check anything whether it is iterable , iterator or not

# %%
# String is iterable object by default .By using iter() function we are converting into iterator object .

# %%
range(6)
# Out:
# range(0, 6)

# %%
r=range(0,6)

# %%
next(r)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 next(r)
#
# TypeError: 'range' object is not an iterator

# %%
#'range' object is not iterator

# %%
a=iter(r)

# %%
a

# %%
next(a)
# Out:
# 0

# %%
next(a)
# Out:
# 1

# %%
# so range function is iterable and we can convert iterable object to iterator object using iter function.
